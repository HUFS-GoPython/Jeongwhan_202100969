# %% [markdown]
# ## 중첩조건문(nested conditional)
#
# - D : if 블록 안에 또다른 if 블록이 있는 경우를 이야기함.
# - 실현 : 들여쓰기로 논리 구분

# %% [markdown]
# # 안좋은 ex1)
# x = 0
# y = 1
# if x == y :
#     print("Block A")
# else:
#     if x<y :
#       print("Block B")
#     else:
#       print("Block C")

# %% [markdown]
# # 안좋은 ex2)
#
# if x>0 :
#     if x < 10 :
#         print("Block A")
#     else:
#         print("Block B")
# else:
#     print("Block C")

# %% [markdown]
# if x==y :
#     #block a
# elif x : y:
#     #block b
# else :
#     # block c

# %% [markdown]
# # 좋은 ex 1)
# if (x>0) and (x<10) : #논리연산자
#     # block a
# else :
#     #block b
#
# # 좋은 방법 2)
#
# if 0<x<10 :
#     # block a
# else :
#     # block b

# %% [markdown]
# ### 논리연산자
# - D : 비교연산자가 여러번 사용될 때 사용하는 것
# - ex) and, or, not
#     - A and B : A-T and B-T (둘 모두 참)
#         (A & B 로도 가능)
#     - A or B : 둘 중 하나만 참이어도 ok
#         (A | B 로도 가능)
#     - not A : ~A
# - 비교연산자의 괄호는 가독성을 위해 쓰는 것(사실 안써도됨. 선택)
# - 한 줄로 이어지는 표현은 파이썬이어서 가능한 것 ( 0<x<10 )

# %% [markdown]
# ### True, False
# - "만약 a가 참이라면, .. "
# a = True

# %% [markdown]
# if a == True :
#     print 안돼 틀린 예라고 안돼
#
# if a : 이렇게 써야함
#     print()

# %% [markdown]
# ### in
# - membership operator
# - 어떤 요소가 그 안에 있는지 확인하고 싶다
# - 비슷한 조건이 여러번 반복될 때 사용 가능

# %%
letter ='k'

#letter가 모음인지 확인하고 싶다: a,e,i,o,u

#if letter == 'a' or letter == 'e' ...

#하지만 in을 쓴다면? 이렇게 가능

#not in..

if letter in ['a', 'e', 'i', 'o', 'u'] : #리스트 요소에 letter와 일치하는 것이 있는가
    print("Yes")     
else :
    print("no")
# Out:
# no

# %%
word = 'abcde'

#word에 모음이 있는지 확인.. 일케하는거 아님. 결국 맞는 방법은 안 알려줬네 

if word in ['a', 'e', 'i', 'o', 'u'] : 
    print("Yes")     
else :
    print("no")
# Out:
# no

# %%
word = 'abcdefu'

word_1 = word[0]
word_2 = word[1]
word_3 = word[2]
word_4 = word[3]
word_5 = word[4]
word_6 = word[5]
word_7 = word[6]

word_list = [word_1,word_2,word_3,word_4,word_5,word_6, word_7]

if word_list in ['a','e','i','o','u'] :
    print('Yes')
else :
    print('No')

# 위 단어에 모음이 잇는지 확인하려면 어떤 식으로 짜야하지?
# Out:
# No

# %% [markdown]
# ### 바다코끼리 연산자 (글케 중요하지는 않음)
# - walrus operator
# - 할당과 테스트를 동시에 하는 기능
# - :=

# %%
tweet_limit = 200
tweet_string = 'blah' * 50 #공백없이 스트링 4*50개 나옴
tweet_string
# Out:
# 'blahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblahblah'

# %%
diff = tweet_limit - len(tweet_string) #difference 
if diff > 0 : 
    print("가능")
else : print("불가능")
# Out:
# 불가능

# %%
#월러스를 쓴다면?

if diff := tweet_limit - len(tweet_string) > 0 :
    print("가능")

# %% [markdown]
# ### Quiz
# - 윤년을 구하는 코드를 짜보자
#     - 연도가 4로 나눠 떨어지면 윤년
#     - 100으로 나눠 떨어지면 안됨
#     - 400으로 나눠 떨어지면 됨
#
# - year를 입력받는다.
# - 'xxx년은 윤년입니다.' / "{}년은 윤년이 아닙니다."

# %%
year = int(input("연도를 입력"))

if (year%4==0) and (year%100!=0) or (year%400==0) :
    print(f"{year}년은 윤년입니다.")

else :
      print(f"{year}년은 윤년이 아닙니다.")
# Out:
# 연도를 입력 4800
# 4800년은 윤년입니다.

# %%
year = int(input('년도를 입력하시오: '))

if (year % 4 == 0) and (year % 100 != 0):
            print(f'{year}년은 윤년입니다.')
elif : year % 400 == 0:
    print(f'{year}년은 윤년입니다.')
else:
    print(f'{year}년은 윤년이 아닙니다.')
# Out:
# 년도를 입력하시오:  2020
# 2020년은 윤년입니다.
# 2020년은 윤년이 아닙니다.

# %%
# Out:
# 20

# %% [markdown]
# # Ch.5

# %% [markdown]
# ## String | 문자열
# - str type
# - 시스템에서 가장 작은 단위 a (크기가 가장 작음)
# - 불변적인 성격을 가짐 (immutable)
#     - 'abcd'에서 안에 있는 b -> a 바꿀수 없음. 그런 의미에서 불변적...
# -  실현 : '', ""로 감싸면 문자열이 됨
#     ex) '24' <-str임
# - ''' or """ - 주석이었지
# - 형 변환은 str()
#
# ## Escape character | 이스케이프 문자
# - 눈에 보이는 대로 인식되지 않는 문자열
# - 실현 : \ + * (character..라고함)
#   ex ) \n(줄바꿈 눌라인?), \t(탭), \b (백스페이스, 잘 안 씀) \' \"
# - print()함수 쓰지 않고 출력할 시에는 형태가 그대로 보임
# - '\n' 출력은 어떻게?
#     -\\n
#     -r'' (raw string)
# - 문자열을 바꾸는 것이 아니라 표면 상의 형태를 말하는 것

# %%
sent= 'hello\bworld I \"m a boy'
print(sent)
sent
# Out:
# hellworld I "m a boy
# 'hello\x08world I "m a boy'

# %% [markdown]
# ### 연산
# - concatenation (+)
#     - '' + '' => 붙이기 (공백없이 붙음)
# - 복제 (*)
#     - '' * 4 => 4번 반복 (얘도 공백없이)

# %%
sent + sent
# Out:
# 'hello\x08world I "m a boyhello\x08world I "m a boy'

# %%
sent*4
# Out:
# 'hello\x08world I "m a boyhello\x08world I "m a boyhello\x08world I "m a boyhello\x08world I "m a boy'

# %% [markdown]
# ### Slicing
# - 지정 범위의 문자열을 추출하는 것
# - 문법: 대괄호 + 오프셋 이용 [<offset>]
#     -[start:end:step]
# - 오프셋은 0부터 시작!!
# - start 포함, end 불포함 (이상, 미만)
# -0일 경우 생략함!!
# - 오프셋은 거꾸로도 가능하다
# 0 1 2 ...
# h e l l o
# -5     -1

# %%
sent, sent[1]
# Out:
# ('hello\x08world I "m a boy', 'e')

# %%
sent[3:4] #처음부터 4까지는 sent[:4]... 주의하자
# Out:
# 'l'

# %%
sent2 = 'hello world     '
len(sent2) #length(공백까지 포함함)
# Out:
# 16

# %%
#처음부터 끝까지 2스텝씩 출력하기

sent[::2]
# Out:
# 'hlowrdI"  o'

# %%
#처음부터 끝까지 역순으로 출력 ?????

sent[::-1]
# Out:
# 'yob a m" I dlrow\x08olleh'

# %%
sent[2]='K' #str의 불변성.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3268/2559795622.py in <module>
# ----> 1 sent[2]='K'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### NLTK
# - natural language toolkit
# - 교육용으로 개발된 자연어처리 패키지
# - 코퍼스 제공하는데 어떤 처리가 되어 있다.
#     - 토크나이즈, 파싱, 태깅, ..

# %%
#!pip install nltk => 터미널로 패키지 설치하는 코드

# %%
import nltk 
nltk.download('book', quiet=True) #dot으로 접근하기
# Out:
# True

# %%
import nltk 
nltk.download('book') #dot으로 접근하기
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\dwin3\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\dwin3\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\dwin3\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\dwin3\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\dwin3\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# ...

# %%
from nltk import book
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
moby = book.text1

# %%
moby.tokens
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
# ...

# %%
# 총 길이
len(moby.tokens)
"""
토큰이란? 프로그래밍에서 단어의 새로운 정의임.(일상생활하고는 좀 다름)
ex) " I'm a boy."=>  i'm, i am, i 'm 뭔소리여 단순히 단어들 기호들?

"""
# Out:
# 260819

# %%
len(moby)
# Out:
# 260819

# %%
#중복되는 단어들을 걸러내자
set(moby.tokens)
# Out:
# {'immensities',
#  'collated',
#  'upraising',
#  'mahogany',
#  'average',
#  'Europa',
#  'base',
#  'church',
#  'natur',
#  'maid',
#  'superior',
#  'uplifted',
#  'quadruped',
#  'gallery',
#  'bids',
#  'unwilted',
#  'bounties',
#  'ranges',
#  'unrecking',
#  'deceitfulness',
#  'joyous',
#  'ascertained',
#  'private',
#  'Commonwealth',
#  'interruptions',
#  'uncontinented',
#  'disordered',
#  'pupils',
#  'wide',
#  'Least',
#  'counterpart',
#  'ruin',
#  'privation',
#  'Himself',
#  'something',
#  'shipkeepers',
#  'beauty',
#  'Johnson',
#  'Year',
#  'grenadier',
#  'Alexander',
#  'twist',
#  'decline',
#  'Trumpet',
#  'untottering',
#  'inhabitant',
#  'incorruption',
#  'endures',
#  'rag',
#  'meridians',
#  'sling',
#  'assailing',
#  'bought',
#  'Accursed',
#  'durst',
#  'joke',
#  'abominated',
#  'unwarrantable',
#  'branded',
#  'beaker',
#  'younger',
#  'foes',
#  'blinded',
#  'Dissect',
#  'phrensied',
#  'roots',
#  'drugged',
#  'oblivious',
# ...

# %% [markdown]
# - set
#     -{a,b,c, ...}
#    - 수학의 집합과 동일한 개념 => 중복 불가능
#                               => 순서 없음
# - list
#     [a,b,c .. .]
#     - 중복 가능
#     - 순서 있음

# %%
cars = ['kia', 'benz', 'porsche', 'kia']
set (cars)
# Out:
# {'benz', 'kia', 'porsche'}

# %%
# 중복 없는 단어 수 
len(set(moby.tokens))
# Out:
# 19317

# %%
#lexical diversity
len(set(moby.tokens))/len(moby.tokens)
# Out:
# 0.07406285585022564

# %%
#오름차순, 내림차순 정렬
sorted(cars)
sorted(cars, reverse=True)
# Out:
# ['porsche', 'kia', 'kia', 'benz']

# %%
#mobydick 정렬하기
sorted(set(moby.tokens), reverse=True) [:10]
# Out:
# ['zoology',
#  'zones',
#  'zoned',
#  'zone',
#  'zodiac',
#  'zig',
#  'zephyr',
#  'zeal',
#  'zay',
#  'zag']

# %% [markdown]
# -text9에서 lexical diversity 구하세요.
# ### 담 수업 실습 퀴즈 1
# -text 6에서 중복 없는 셋 내림차순 정렬하기
#     -a. 앞에서 단어 10개 추출하기
#     -b. 조건문 연습 : 'z'가 있으면 대문자로 바꾸기, 'z'가 없는데 4자 이상이면 끝 글자 대문자로 바꾸기
#
# ### Quiz2.
# - 주민등록번호, 휴대폰 번호, 이메일 입력받는다.
#     - 주민번호, 휴대폰은 숫자만 입력 (-없다)
#     - 이메일은 아이디만 입력
#
# - 출력:
#     -" 당신은 {}년 {}월 {}일 출생의 {남성/여성}입니다."
#     - 휴대폰번호 : {} #하이픈으로 연결하기
#     - 이메일주소 : {아이디}@gmail.com 으로 출력

# %% [markdown]
# 출석문제 복습
#
# #1
#
# #1. 다음 중 True인 것은?
# a) 0 and 1 => and이므로 둘 다 true여야 함 => false
# b) 0 or 1 => or , 1이 true임 => True
# c) string = '0' => str은 값이 있으면 True인듯.
# d) A = [] => False가 됨.
# e) B = [0] => 그냥 안에 값이 있으면 (공집합이 아니면) True인듯

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool('0')
# Out:
# True

# %%
string='dfsd'

bool(string)
# Out:
# True

# %%
A = []
bool(A)
# Out:
# False

# %%
B = [0]
bool(B)
# Out:
# True

# %%
B = [1]
bool(B)
# Out:
# True

# %%
#2. 편의점 매출 계산
"""
조건1: 총 매출 = (소비자가 - 원가) * 개수
조건2: 5개 이상 구매 시 전체 물품의 15% 할인
 (할인 적용 품목 범위는 둘다 가능함)
한 고객이 다음과 같이 물건을 구입했다고 할 떄, 편의점의 매출을 계산하시오.
출력 조건:
 - 최대한 모든 리터럴을 변수에 담을 것.
 - 출력값은 총 매출액(정수)
 비요뜨 삼각김밥 콜라 바나나 홈런볼
원가     480  900  380 1050  770
소비자가 1300 2500 800 3200 1500
개수 3 5 6 2 4
     A     B     C     D       E  
"""

# 어떻게 하면 좋을까... 그냥 계산하는게 제일 편할듯.

sum_a = (1300-480)*3
sum_b = (2500-900)*5
sum_c = (800-380)*6 
sum_d = (3200-1050)*2
sum_e = (1500-770)*4

sum_total=(sum_a+sum_b+sum_c+sum_d+sum_e)/100*85

print(sum_total)
# Out:
# 17170.0

# %%
#3. 마이클이 흙을 나른다고 가정하자.
"""
옮겨야 할 흙은 총 n킬로그램이고, 마이클은 3kg씩 혹은 5kg씩 나를 수 있다.
최대한 적은 노력으로 모든 흙을 나를 수 있는 코드를 작성하라.
(단, 나르는 흙의 양이 총량과 정확하게 떨어지지 않으면 총량을 살짝 넘겨야 한다.)
출력 조건:
 - n은 랜덤으로 주어진다.
 - 출력값 = (3kg 나르는 횟수, 5kg 나르는 횟수)
 
 이것도 모르겠다..
"""
# 참고용

import random
n = random.randint(10, 100)

print(f" 총 옮겨야할 흙은 {n}kg")
# Out:
#  총 옮겨야할 흙은 88kg

# %%
#4. 달팽이가 높이 350미터인 나무 막대를 올라간다.
"""
조건1: 달팽이는 낮에 5미터 올라간다.
조건2: 밤에는 2미터 미끄러진다.
조건3: 정상에 올라간 후에는 미끄러지지 않는다.
달팽이가 막대기 정상에 올라가려면 며칠이 걸리는지 코드를 짜서 프린트하시오.
(모든 리터럴은 변수에 담겨야 한다. 코드 및 정답을 모두 제출한다.)

모르겠다 질문하자 
"""

len=350


snail_run=
# Out:
#   File "C:\Users\dwin3\AppData\Local\Temp/ipykernel_9936/766928611.py", line 10
#     350m
#        ^
# SyntaxError: invalid syntax

# %%
#5. 세 수를 입력 받고 가장 큰 수를 찾는 코드를 작성하시오.
"""
예: 12, 14, 15 입력 받았다면 15
* 조건식을 위한 문제이기 때문에 max() 함수는 인정하지 않음.
"""

num1=input("1드루와")
num2=input("2드루와")
num3=input("3드루와")

if num1>num2 : 
    if num1>num3 :
        print(num1)
    else : #num1<=num3
        print(num3)
else : #num1<=num2겠지
    if num2>num3:
        print(num2)
    else : #num2<=num3
        print(num3)
        
""" 계속 오류 났음. 
num3<num1<num2일때, 자꾸 이상한 값이 나왔음.. 
왜인지 테스트 
"""

type(num1)

type(num2)

type(num3)
# Out:
# 1드루와 10
# 2드루와 30
# 3드루와 5
# D
# str

# %%
# int 값으로 해줌을 통해 해결함.. 근데 뭐가 다른거지? 

num1=int(input("1드루와"))
num2=int(input("2드루와"))
num3=int(input("3드루와"))

if num1>num2 : 
    if num1>num3 :
        print(num1)
    else : #num1<=num3
        print(num3)
else : #num1<=num2겠지
    if num2>num3:
        print(num2)
    else : #num2<=num3
        print(num3)
# Out:
# 1드루와 10
# 2드루와 30
# 3드루와 5
# 30

# %%
""" 
다른 사람 코드 참고...
음 받은 값을 따로 변수로 지정하고, 그 후 비교하는 아이디어가
무슨 차이를 주는지 관찰
"""

num1=int(input("1드루와"))
num2=int(input("2드루와"))
num3=int(input("3드루와"))

maximum = num1

if maximum < num2 :
    maximum = num2

if maximum < num3 :
    maximum = num3
    
print(maximum)

# print를 한 줄로 쓸 수 있게 됨으로써 코드 쓰는게 깔끔해짐. 

"""
뭐가 달랐지???
조금만 더 일반화해보자면...
숫자를 비교하는 아이디어의 논리구조...
그냥 각자 비교하는게 아니라 변수를 하나 만들어 준게
되게 좋았던 것 같음! 
"""
# Out:
# 1드루와 5
# 2드루와 6345
# 3드루와 214135
# 214135

# %%
"""
-text 6에서 중복 없는 셋 내림차순 정렬하기
    -a. 앞에서 단어 10개 추출하기
    -b. 조건문 연습 : 'z'가 있으면 대문자로 바꾸기, 'z'가 없는데 4자 이상이면 끝 글자 대문자로 바꾸기
"""

import nltk
nltk.download('book', quiet=True)
from nltk import book
txt1=book.text6

txt1.tokens

set(txt1)
txt1_sorted=sorted(txt1, reverse=True) [:10]


# 대문자로 어떻게 바꿔야할지 모르겠습니다!

# %%
"""
### Quiz2.
- 주민등록번호, 휴대폰 번호, 이메일 입력받는다.
    - 주민번호, 휴대폰은 숫자만 입력 (-없다)
    - 이메일은 아이디만 입력   

- 출력:
    -" 당신은 {}년 {}월 {}일 출생의 {남성/여성}입니다."
    - 휴대폰번호 : {} #하이픈으로 연결하기
    - 이메일주소 : {아이디}@gmail.com 으로 출력
"""

id_num=input("주민등록번호를 하이픈 없이 입력하세요")
phone_num=input("전화번호를 하이픈 없이 입력하세요")
email=input("이메일 아이디만 입력하세요")
#9906221
#0123456
if id_num[6] == '1' :
    print(f"당신은 19{id_num[:2]}년 {id_num[2:4]}월 {id_num[4:6]}일 출생의 남성입니다.")
elif id_num[6] == '2' :
    print(f"당신은 19{id_num[:2]}년 {id_num[2:4]}월 {id_num[4:6]}일 출생의 여성입니다.")
elif id_num[6] == '3' :
    print(f"당신은 20{id_num[:2]}년 {id_num[2:4]}월 {id_num[4:6]}일 출생의 남성입니다.")
elif id_num[6] == '4' :
    print(f"당신은 20{id_num[:2]}년 {id_num[2:4]}월 {id_num[4:6]}일 출생의 여성입니다.")
else :
    print("주민등록번호가 잘못되었습니다.")
# 한 줄로 쓸 수 없을까?

print(f"휴대폰 번호 : {phone_num[:3]}-{phone_num[3:7]}-{phone_num[7:]}")

print(f"이메일주소 : {email}@gmail.com")
# Out:
# 주민등록번호를 하이픈 없이 입력하세요 0202023451234
# 전화번호를 하이픈 없이 입력하세요 01055451515
# 이메일 아이디만 입력하세요 hellohellohowlow
# 당신은 2002년 02월 02일 출생의 남성입니다.
# 휴대폰 번호 : 010-5545-1515
# 이메일주소 : hellohellohowlow@gmail.com
